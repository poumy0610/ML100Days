# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    請完成這個 Function 後往下執行
    """
    mse = MSE = sum((y - yp)** 2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 167.850
# The Mean absolute error is 10.188

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# https://www.kaggle.com/kimjihoo/coronavirusdataset?select=PatientInfo.csv
#
# 1. 你選的這組資料為何重要
# 該資料集中，與時間相關的內容，記載著COVID-19病患的發病時間、確診時間、出院時間、離世時間等，對醫院來說可以用以評估收治一個新冠肺炎病患須提供幾天的病床，以確保醫院本身可以維持一定的空床率給其他需要被醫治的病患。此資料集為持續更新的，對於韓國政府來說，比較好掌控各個感染者所散播出去的疫情狀況，藉此可以評斷是否為"超級傳染者"。各個病患的年齡、性別、國籍等資料也可以用來評斷什麼樣的人較容易受感染。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# KCDC (Korea Centers for Disease Control & Prevention) 的報告以及地方政府的資料。
# 3. 蒐集而來的資料型態為何
# int, text, date
# 4. 這組資料想解決的問題如何評估
# 將資料轉成可視化，做為疾病防治決策的判斷依據。以及對資料進行分析，掌握確診者的相關資訊，降低疾病的擴散率，
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 我認為提升業績的第一步可以先從提升載客數開始。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 可以先依目前的載客狀況，分析各時段較熱門的景點。也可以從google上的熱門時段資訊或是大型活動時段資訊，作為各地區的人潮評估依據，提前部署車隊，提升載客數。
# 3. 蒐集而來的資料型態為何
# 時間(time)、地點(text or 座標)、人數(int)。
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 車隊本身的載客數需透過系統去做紀錄，每次載客金額都須納入，就能計算出各部車子每天載客數量多寡，以統計的方式比較前後載客數的差別，即可知道該假設的成效(是否載客數多即可提升業績、是否透過問題2的方式蒐集資料作為部署車輛依據即可提升載客數)。
