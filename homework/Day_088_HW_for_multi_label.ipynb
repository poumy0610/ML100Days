# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
import os
import keras
import tensorflow as tf

os.environ["CUDA_VISIBLE_DEVICES"] = "0"
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))

physical_devices = tf.config.list_physical_devices('GPU') 
tf.config.experimental.set_memory_growth(physical_devices[0], True)
# Out:
# Num GPUs Available:  1

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

"""
建立神經網路，並加入 BN layer
"""
def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
from keras.callbacks import Callback
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import multilabel_confusion_matrix

# Record_fp_tp
class Record_tp_tn(Callback):
    """Code Here
    撰寫一個紀錄 ture positive 與 true negative 數量的 callbacks    
    """
    def __init__(self, val_data=(x_test, y_test)):
        self.validation_data = val_data
        
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ["val_auc", "val_f1sc", "val_fp", "val_fn", "val_tp", "val_tn"]
        for i in record_items:
            try:
                if i not in self.params['metrics']:
                    self.params['metrics'].append(i)
            except:
                self.params['metrics']=i
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = y_pred.argmax(axis = 1)
        val_f1sc = f1_score(y_true = y_true, y_pred = y_pred, average="weighted")
        confuse = multilabel_confusion_matrix(y_true, y_pred)
        print (confuse)

        num_classes = confuse.shape[0]
        print ("numclasses: ", num_classes)

        val_tp = val_tn = 0
        for i in range(num_classes):
            val_tp += confuse[i,0,0]    
            val_tn += confuse[i,1,1]

        val_tp /= num_classes
        val_tn /= num_classes

        logs["val_tp"] = val_tp
        logs["val_tn"] = val_tn
        logs["val_f1sc"]= val_f1sc

rec_tptn = Record_tp_tn()

# %%
model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""
model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test), 
          shuffle=True,
          callbacks=[rec_tptn])

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 3072)]            0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization (BatchNo (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Epoch 1/25
#  2/49 [>.............................] - ETA: 20s - loss: 3.0479 - accuracy: 0.0933WARNING:tensorflow:Method (on_train_batch_end) is slow compared to the batch update (0.292969). Check your callbacks.
# 47/49 [===========================>..] - ETA: 0s - loss: 2.2029 - accuracy: 0.2685 ETA: 0s - loss: 2.2656 - accuracy[[[5980 3020]
#   [ 381  619]]
#
#  [[8897  103]
#   [ 940   60]]
#
#  [[8709  291]
#   [ 905   95]]
#
#  [[7574 1426]
#   [ 733  267]]
#
#  [[8989   11]
#   [ 998    2]]
#
#  [[8289  711]
#   [ 803  197]]
#
#  [[8886  114]
#   [ 955   45]]
#
#  [[8939   61]
#   [ 975   25]]
#
#  [[7203 1797]
#   [ 370  630]]
#
#  [[8627  373]
#   [ 847  153]]]
# numclasses:  10
# 49/49 [==============================] - 6s 115ms/step - loss: 2.1892 - accuracy: 0.2721 - val_loss: 2.1290 - val_accuracy: 0.2093 - val_tp: 8209.3000 - val_tn: 209.3000 - val_f1sc: 0.1608
# Epoch 2/25
# 49/49 [==============================] - ETA: 0s - loss: 1.7318 - accuracy: 0.3925[[[7320 1680]
#   [ 360  640]]
#
#  [[8824  176]
#   [ 828  172]]
#
#  [[8099  901]
#   [ 688  312]]
#
#  [[7522 1478]
#   [ 656  344]]
#
#  [[8976   24]
#   [ 969   31]]
#
#  [[7614 1386]
#   [ 611  389]]
#
#  [[8909   91]
#   [ 916   84]]
#
#  [[8779  221]
#   [ 819  181]]
#
#  [[8312  688]
#   [ 502  498]]
#
#  [[8622  378]
#   [ 674  326]]]
# numclasses:  10
# 49/49 [==============================] - 2s 36ms/step - loss: 1.7318 - accuracy: 0.3925 - val_loss: 1.9502 - val_accuracy: 0.2977 - val_tp: 8297.7000 - val_tn: 297.7000 - val_f1sc: 0.2745
# Epoch 3/25
# 49/49 [==============================] - ETA: 0s - loss: 1.6132 - accuracy: 0.4325[[[7612 1388]
#   [ 334  666]]
#
#  [[8738  262]
#   [ 680  320]]
#
#  [[8280  720]
#   [ 688  312]]
#
#  [[7224 1776]
#   [ 542  458]]
#
#  [[8917   83]
#   [ 901   99]]
#
#  [[8179  821]
#   [ 673  327]]
#
#  [[8712  288]
#   [ 768  232]]
#
#  [[8665  335]
#   [ 664  336]]
#
#  [[8483  517]
#   [ 500  500]]
#
#  [[8733  267]
#   [ 707  293]]]
# numclasses:  10
# 49/49 [==============================] - 2s 37ms/step - loss: 1.6132 - accuracy: 0.4325 - val_loss: 1.8334 - val_accuracy: 0.3543 - val_tp: 8354.3000 - val_tn: 354.3000 - val_f1sc: 0.3482
# Epoch 4/25
# 49/49 [==============================] - ETA: 0s - loss: 1.5422 - accuracy: 0.4590[[[8157  843]
#   [ 410  590]]
#
#  [[8677  323]
#   [ 605  395]]
#
#  [[8322  678]
#   [ 665  335]]
#
#  [[7835 1165]
#   [ 624  376]]
#
#  [[8681  319]
#   [ 749  251]]
#
#  [[8111  889]
#   [ 611  389]]
#
#  [[8662  338]
#   [ 695  305]]
#
#  [[8411  589]
#   [ 522  478]]
#
#  [[8438  562]
#   [ 421  579]]
#
#  [[8737  263]
#   [ 667  333]]]
# numclasses:  10
# 49/49 [==============================] - 2s 37ms/step - loss: 1.5422 - accuracy: 0.4590 - val_loss: 1.7139 - val_accuracy: 0.4031 - val_tp: 8403.1000 - val_tn: 403.1000 - val_f1sc: 0.4027
# Epoch 5/25
# 49/49 [==============================] - ETA: 0s - loss: 1.4872 - accuracy: 0.4787[[[8422  578]
#   [ 448  552]]
#
#  [[8606  394]
#   [ 509  491]]
#
#  [[8227  773]
#   [ 612  388]]
#
#  [[7893 1107]
#   [ 601  399]]
#
#  [[8690  310]
#   [ 739  261]]
#
#  [[8404  596]
#   [ 671  329]]
#
#  [[8413  587]
#   [ 548  452]]
#
#  [[8434  566]
#   [ 493  507]]
#
#  [[8555  445]
#   [ 406  594]]
#
#  [[8712  288]
#   [ 617  383]]]
# numclasses:  10
# 49/49 [==============================] - 2s 38ms/step - loss: 1.4872 - accuracy: 0.4787 - val_loss: 1.6331 - val_accuracy: 0.4356 - val_tp: 8435.6000 - val_tn: 435.6000 - val_f1sc: 0.4364
# Epoch 6/25
# 49/49 [==============================] - ETA: 0s - loss: 1.4450 - accuracy: 0.4940[[[8440  560]
#   [ 434  566]]
#
#  [[8644  356]
#   [ 512  488]]
#
#  [[8407  593]
#   [ 664  336]]
#
#  [[7882 1118]
#   [ 588  412]]
#
#  [[8555  445]
#   [ 666  334]]
#
#  [[8379  621]
#   [ 650  350]]
#
#  [[8454  546]
#   [ 546  454]]
#
#  [[8604  396]
#   [ 543  457]]
#
#  [[8480  520]
#   [ 355  645]]
#
#  [[8633  367]
#   [ 564  436]]]
# numclasses:  10
# 49/49 [==============================] - 2s 36ms/step - loss: 1.4450 - accuracy: 0.4940 - val_loss: 1.5791 - val_accuracy: 0.4478 - val_tp: 8447.8000 - val_tn: 447.8000 - val_f1sc: 0.4493
# Epoch 7/25
# 48/49 [============================>.] - ETA: 0s - loss: 1.4075 - accuracy: 0.5081[[[8687  313]
#   [ 542  458]]
#
#  [[8468  532]
#   [ 425  575]]
#
#  [[8565  435]
#   [ 743  257]]
#
#  [[8039  961]
#   [ 618  382]]
#
#  [[8540  460]
#   [ 650  350]]
#
#  [[8170  830]
#   [ 574  426]]
#
#  [[8451  549]
#   [ 534  466]]
#
#  [[8560  440]
#   [ 513  487]]
#
#  [[8492  508]
#   [ 353  647]]
#
#  [[8544  456]
#   [ 532  468]]]
# numclasses:  10
# 49/49 [==============================] - 2s 36ms/step - loss: 1.4069 - accuracy: 0.5086 - val_loss: 1.5485 - val_accuracy: 0.4516 - val_tp: 8451.6000 - val_tn: 451.6000 - val_f1sc: 0.4512
# Epoch 8/25
# 49/49 [==============================] - ETA: 0s - loss: 1.3701 - accuracy: 0.5221[[[8614  386]
#   [ 476  524]]
#
#  [[8486  514]
#   [ 400  600]]
#
#  [[8505  495]
#   [ 700  300]]
#
#  [[8271  729]
#   [ 657  343]]
#
#  [[8421  579]
#   [ 600  400]]
#
#  [[8413  587]
#   [ 631  369]]
#
#  [[8391  609]
#   [ 477  523]]
#
#  [[8412  588]
#   [ 456  544]]
#
#  [[8613  387]
#   [ 395  605]]
#
#  [[8564  436]
#   [ 518  482]]]
# numclasses:  10
# 49/49 [==============================] - 2s 37ms/step - loss: 1.3701 - accuracy: 0.5221 - val_loss: 1.5107 - val_accuracy: 0.4690 - val_tp: 8469.0000 - val_tn: 469.0000 - val_f1sc: 0.4674
# Epoch 9/25
# 49/49 [==============================] - ETA: 0s - loss: 1.3381 - accuracy: 0.5321[[[8448  552]
#   [ 396  604]]
#
#  [[8603  397]
#   [ 448  552]]
#
#  [[8464  536]
#   [ 680  320]]
#
#  [[8193  807]
#   [ 619  381]]
#
#  [[8492  508]
#   [ 627  373]]
#
#  [[8518  482]
#   [ 666  334]]
#
#  [[8331  669]
#   [ 450  550]]
#
#  [[8562  438]
#   [ 474  526]]
#
#  [[8633  367]
#   [ 401  599]]
#
#  [[8522  478]
#   [ 473  527]]]
# numclasses:  10
# 49/49 [==============================] - 2s 35ms/step - loss: 1.3381 - accuracy: 0.5321 - val_loss: 1.4860 - val_accuracy: 0.4766 - val_tp: 8476.6000 - val_tn: 476.6000 - val_f1sc: 0.4751
# Epoch 10/25
# 47/49 [===========================>..] - ETA: 0s - loss: 1.3072 - accuracy: 0.5462[[[8718  282]
#   [ 543  457]]
#
#  [[8531  469]
#   [ 409  591]]
#
#  [[8295  705]
#   [ 625  375]]
#
#  [[8368  632]
#   [ 685  315]]
#
#  [[8515  485]
#   [ 635  365]]
#
#  [[8517  483]
#   [ 656  344]]
#
#  [[8327  673]
#   [ 442  558]]
#
#  [[8522  478]
#   [ 472  528]]
#
#  [[8369  631]
#   [ 288  712]]
#
#  [[8572  428]
#   [ 511  489]]]
# numclasses:  10
# 49/49 [==============================] - 2s 37ms/step - loss: 1.3080 - accuracy: 0.5456 - val_loss: 1.4885 - val_accuracy: 0.4734 - val_tp: 8473.4000 - val_tn: 473.4000 - val_f1sc: 0.4699
# Epoch 11/25
# 49/49 [==============================] - ETA: 0s - loss: 1.2810 - accuracy: 0.5564[[[8611  389]
#   [ 458  542]]
#
#  [[8512  488]
#   [ 391  609]]
#
#  [[8419  581]
#   [ 656  344]]
#
#  [[8466  534]
#   [ 707  293]]
#
#  [[8461  539]
#   [ 602  398]]
#
#  [[8499  501]
#   [ 636  364]]
#
#  [[8431  569]
#   [ 466  534]]
#
#  [[8134  866]
#   [ 357  643]]
#
#  [[8621  379]
#   [ 385  615]]
#
#  [[8651  349]
#   [ 537  463]]]
# numclasses:  10
# 49/49 [==============================] - 2s 36ms/step - loss: 1.2810 - accuracy: 0.5564 - val_loss: 1.4805 - val_accuracy: 0.4805 - val_tp: 8480.5000 - val_tn: 480.5000 - val_f1sc: 0.4770
# Epoch 12/25
# 49/49 [==============================] - ETA: 0s - loss: 1.2538 - accuracy: 0.5664[[[8588  412]
#   [ 460  540]]
#
#  [[8652  348]
#   [ 464  536]]
#
#  [[8356  644]
#   [ 639  361]]
#
#  [[8604  396]
#   [ 766  234]]
#
#  [[8137  863]
#   [ 509  491]]
#
#  [[8341  659]
#   [ 581  419]]
#
#  [[8627  373]
#   [ 575  425]]
#
#  [[8345  655]
#   [ 414  586]]
#
#  [[8598  402]
#   [ 368  632]]
#
#  [[8512  488]
#   [ 464  536]]]
# numclasses:  10
# 49/49 [==============================] - 2s 35ms/step - loss: 1.2538 - accuracy: 0.5664 - val_loss: 1.4780 - val_accuracy: 0.4760 - val_tp: 8476.0000 - val_tn: 476.0000 - val_f1sc: 0.4737
# Epoch 13/25
# 48/49 [============================>.] - ETA: 0s - loss: 1.2268 - accuracy: 0.5762[[[8661  339]
#   [ 478  522]]
#
#  [[8550  450]
#   [ 408  592]]
#
#  [[8451  549]
#   [ 674  326]]
#
#  [[8493  507]
#   [ 718  282]]
#
#  [[8326  674]
#   [ 550  450]]
#
#  [[8429  571]
#   [ 592  408]]
#
#  [[8415  585]
#   [ 462  538]]
#
#  [[8476  524]
#   [ 430  570]]
#
#  [[8517  483]
#   [ 334  666]]
#
#  [[8540  460]
#   [ 496  504]]]
# numclasses:  10
# 49/49 [==============================] - 2s 37ms/step - loss: 1.2264 - accuracy: 0.5763 - val_loss: 1.4567 - val_accuracy: 0.4858 - val_tp: 8485.8000 - val_tn: 485.8000 - val_f1sc: 0.4824
# Epoch 14/25
# 49/49 [==============================] - ETA: 0s - loss: 1.2031 - accuracy: 0.5832[[[8610  390]
#   [ 455  545]]
#
#  [[8484  516]
#   [ 370  630]]
#
#  [[8212  788]
#   [ 573  427]]
#
#  [[8374  626]
#   [ 692  308]]
#
#  [[8493  507]
#   [ 619  381]]
#
#  [[8343  657]
#   [ 596  404]]
#
#  [[8590  410]
#   [ 541  459]]
#
#  [[8573  427]
#   [ 480  520]]
#
#  [[8550  450]
#   [ 337  663]]
#
#  [[8592  408]
#   [ 516  484]]]
# numclasses:  10
# 49/49 [==============================] - 2s 35ms/step - loss: 1.2031 - accuracy: 0.5832 - val_loss: 1.4553 - val_accuracy: 0.4821 - val_tp: 8482.1000 - val_tn: 482.1000 - val_f1sc: 0.4815
# Epoch 15/25
# 49/49 [==============================] - ETA: 0s - loss: 1.1789 - accuracy: 0.5924[[[8402  598]
#   [ 363  637]]
#
#  [[8560  440]
#   [ 402  598]]
#
#  [[8691  309]
#   [ 761  239]]
#
#  [[8360  640]
#   [ 689  311]]
#
#  [[8429  571]
#   [ 577  423]]
#
#  [[8372  628]
#   [ 599  401]]
#
#  [[8543  457]
#   [ 503  497]]
#
#  [[8251  749]
#   [ 362  638]]
#
#  [[8678  322]
#   [ 402  598]]
#
#  [[8560  440]
#   [ 496  504]]]
# numclasses:  10
# 49/49 [==============================] - 2s 36ms/step - loss: 1.1789 - accuracy: 0.5924 - val_loss: 1.4667 - val_accuracy: 0.4846 - val_tp: 8484.6000 - val_tn: 484.6000 - val_f1sc: 0.4789
# Epoch 16/25
# 49/49 [==============================] - ETA: 0s - loss: 1.1569 - accuracy: 0.6010[[[8718  282]
#   [ 534  466]]
#
#  [[8516  484]
#   [ 374  626]]
#
#  [[8511  489]
#   [ 662  338]]
#
#  [[8466  534]
#   [ 696  304]]
#
#  [[8537  463]
#   [ 615  385]]
#
#  [[8369  631]
#   [ 582  418]]
#
#  [[8246  754]
#   [ 374  626]]
#
#  [[8474  526]
#   [ 435  565]]
#
#  [[8551  449]
#   [ 338  662]]
#
#  [[8525  475]
#   [ 477  523]]]
# numclasses:  10
# 49/49 [==============================] - 2s 35ms/step - loss: 1.1569 - accuracy: 0.6010 - val_loss: 1.4594 - val_accuracy: 0.4913 - val_tp: 8491.3000 - val_tn: 491.3000 - val_f1sc: 0.4869
# Epoch 17/25
# 47/49 [===========================>..] - ETA: 0s - loss: 1.1322 - accuracy: 0.6102[[[8569  431]
#   [ 419  581]]
#
#  [[8496  504]
#   [ 384  616]]
#
#  [[8551  449]
#   [ 690  310]]
#
#  [[8445  555]
#   [ 714  286]]
#
#  [[8370  630]
#   [ 554  446]]
#
#  [[8391  609]
#   [ 581  419]]
#
#  [[8643  357]
#   [ 538  462]]
#
#  [[8422  578]
#   [ 422  578]]
#
#  [[8623  377]
#   [ 375  625]]
#
#  [[8393  607]
#   [ 420  580]]]
# numclasses:  10
# 49/49 [==============================] - 2s 37ms/step - loss: 1.1331 - accuracy: 0.6099 - val_loss: 1.4580 - val_accuracy: 0.4903 - val_tp: 8490.3000 - val_tn: 490.3000 - val_f1sc: 0.4864
# Epoch 18/25
# 49/49 [==============================] - ETA: 0s - loss: 1.1132 - accuracy: 0.6162[[[8640  360]
#   [ 455  545]]
#
#  [[8523  477]
#   [ 387  613]]
#
#  [[8603  397]
#   [ 719  281]]
#
#  [[8297  703]
#   [ 669  331]]
#
#  [[8419  581]
#   [ 544  456]]
#
#  [[8359  641]
#   [ 563  437]]
#
#  [[8434  566]
#   [ 435  565]]
#
#  [[8566  434]
#   [ 476  524]]
#
#  [[8603  397]
#   [ 362  638]]
#
#  [[8483  517]
#   [ 463  537]]]
# numclasses:  10
# 49/49 [==============================] - 2s 36ms/step - loss: 1.1132 - accuracy: 0.6162 - val_loss: 1.4478 - val_accuracy: 0.4927 - val_tp: 8492.7000 - val_tn: 492.7000 - val_f1sc: 0.4903
# Epoch 19/25
# 49/49 [==============================] - ETA: 0s - loss: 1.0894 - accuracy: 0.6258[[[8691  309]
#   [ 473  527]]
#
#  [[8657  343]
#   [ 433  567]]
#
#  [[8332  668]
#   [ 607  393]]
#
#  [[8452  548]
#   [ 710  290]]
#
#  [[8354  646]
#   [ 539  461]]
#
#  [[8408  592]
#   [ 595  405]]
#
#  [[8403  597]
#   [ 430  570]]
#
#  [[8551  449]
#   [ 451  549]]
#
#  [[8650  350]
#   [ 382  618]]
#
#  [[8450  550]
#   [ 432  568]]]
# numclasses:  10
# 49/49 [==============================] - 2s 36ms/step - loss: 1.0894 - accuracy: 0.6258 - val_loss: 1.4508 - val_accuracy: 0.4948 - val_tp: 8494.8000 - val_tn: 494.8000 - val_f1sc: 0.4948
# Epoch 20/25
# 47/49 [===========================>..] - ETA: 0s - loss: 1.0665 - accuracy: 0.6343[[[8597  403]
#   [ 443  557]]
#
#  [[8608  392]
#   [ 426  574]]
#
#  [[8514  486]
#   [ 690  310]]
#
#  [[8353  647]
#   [ 678  322]]
#
#  [[8529  471]
#   [ 601  399]]
#
#  [[8326  674]
#   [ 572  428]]
#
#  [[8502  498]
#   [ 455  545]]
#
#  [[8498  502]
#   [ 433  567]]
#
#  [[8458  542]
#   [ 314  686]]
#
#  [[8531  469]
#   [ 472  528]]]
# numclasses:  10
# 49/49 [==============================] - 2s 39ms/step - loss: 1.0665 - accuracy: 0.6347 - val_loss: 1.4416 - val_accuracy: 0.4916 - val_tp: 8491.6000 - val_tn: 491.6000 - val_f1sc: 0.4885
# Epoch 21/25
# 47/49 [===========================>..] - ETA: 0s - loss: 1.0457 - accuracy: 0.6430[[[8688  312]
#   [ 472  528]]
#
#  [[8660  340]
#   [ 450  550]]
#
#  [[8638  362]
#   [ 741  259]]
#
#  [[8310  690]
#   [ 690  310]]
#
#  [[8211  789]
#   [ 510  490]]
#
#  [[8366  634]
#   [ 599  401]]
#
#  [[8421  579]
#   [ 424  576]]
#
#  [[8504  496]
#   [ 430  570]]
#
#  [[8637  363]
#   [ 362  638]]
#
#  [[8459  541]
#   [ 428  572]]]
# numclasses:  10
# 49/49 [==============================] - 2s 36ms/step - loss: 1.0461 - accuracy: 0.6428 - val_loss: 1.4551 - val_accuracy: 0.4894 - val_tp: 8489.4000 - val_tn: 489.4000 - val_f1sc: 0.4875
# Epoch 22/25
# 49/49 [==============================] - ETA: 0s - loss: 1.0256 - accuracy: 0.6507[[[8547  453]
#   [ 419  581]]
#
#  [[8601  399]
#   [ 398  602]]
#
#  [[8330  670]
#   [ 600  400]]
#
#  [[8403  597]
#   [ 700  300]]
#
#  [[8527  473]
#   [ 614  386]]
#
#  [[8368  632]
#   [ 557  443]]
#
#  [[8446  554]
#   [ 446  554]]
#
#  [[8690  310]
#   [ 506  494]]
#
#  [[8431  569]
#   [ 302  698]]
#
#  [[8595  405]
#   [ 520  480]]]
# numclasses:  10
# 49/49 [==============================] - 2s 36ms/step - loss: 1.0256 - accuracy: 0.6507 - val_loss: 1.4596 - val_accuracy: 0.4938 - val_tp: 8493.8000 - val_tn: 493.8000 - val_f1sc: 0.4916
# Epoch 23/25
# 49/49 [==============================] - ETA: 0s - loss: 1.0049 - accuracy: 0.6587[[[8631  369]
#   [ 444  556]]
#
#  [[8578  422]
#   [ 412  588]]
#
#  [[8457  543]
#   [ 639  361]]
#
#  [[8434  566]
#   [ 691  309]]
#
#  [[8537  463]
#   [ 603  397]]
#
#  [[8332  668]
#   [ 573  427]]
#
#  [[8392  608]
#   [ 407  593]]
#
#  [[8587  413]
#   [ 465  535]]
#
#  [[8550  450]
#   [ 348  652]]
#
#  [[8489  511]
#   [ 431  569]]]
# numclasses:  10
# 49/49 [==============================] - 2s 36ms/step - loss: 1.0049 - accuracy: 0.6587 - val_loss: 1.4487 - val_accuracy: 0.4987 - val_tp: 8498.7000 - val_tn: 498.7000 - val_f1sc: 0.4962
# Epoch 24/25
# 49/49 [==============================] - ETA: 0s - loss: 0.9834 - accuracy: 0.6671[[[8678  322]
#   [ 471  529]]
#
#  [[8629  371]
#   [ 410  590]]
#
#  [[8555  445]
#   [ 672  328]]
#
#  [[8301  699]
#   [ 662  338]]
#
#  [[8453  547]
#   [ 543  457]]
#
#  [[8244  756]
#   [ 533  467]]
#
#  [[8433  567]
#   [ 420  580]]
#
#  [[8578  422]
#   [ 458  542]]
#
#  [[8592  408]
#   [ 355  645]]
#
#  [[8557  443]
#   [ 456  544]]]
# numclasses:  10
# 49/49 [==============================] - 2s 36ms/step - loss: 0.9834 - accuracy: 0.6671 - val_loss: 1.4496 - val_accuracy: 0.5020 - val_tp: 8502.0000 - val_tn: 502.0000 - val_f1sc: 0.5020
# Epoch 25/25
# 48/49 [============================>.] - ETA: 0s - loss: 0.9623 - accuracy: 0.6781[[[8636  364]
#   [ 469  531]]
#
#  [[8580  420]
#   [ 404  596]]
#
#  [[8442  558]
#   [ 635  365]]
#
#  [[8402  598]
#   [ 693  307]]
#
#  [[8377  623]
#   [ 542  458]]
#
#  [[8328  672]
#   [ 556  444]]
#
#  [[8530  470]
#   [ 467  533]]
#
#  [[8506  494]
#   [ 426  574]]
#
#  [[8673  327]
#   [ 408  592]]
#
#  [[8491  509]
#   [ 435  565]]]
# numclasses:  10
# 49/49 [==============================] - 2s 37ms/step - loss: 0.9619 - accuracy: 0.6780 - val_loss: 1.4579 - val_accuracy: 0.4965 - val_tp: 8496.5000 - val_tn: 496.5000 - val_f1sc: 0.4963

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
